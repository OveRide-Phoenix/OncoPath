# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import cv2
import random

import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import torch
import torch.optim as optim
from torch.utils.data import Dataset
from PIL import Image
import torch.nn as nn

import warnings
warnings.filterwarnings("ignore")

import glob

from sklearn.model_selection import train_test_split

# %%
masks = glob.glob("Dataset_BUSI_with_GT/*/*_mask.png")

# %%
masks[1:4]
# Out:
# ['Dataset_BUSI_with_GT\\benign\\benign (10)_mask.png',
#  'Dataset_BUSI_with_GT\\benign\\benign (100)_mask.png',
#  'Dataset_BUSI_with_GT\\benign\\benign (101)_mask.png']

# %%
images = [mask_images.replace("_mask", "") for mask_images in masks]

# %%
series = list(zip(images, masks))

# %%
series[:4]
# Out:
# [('Dataset_BUSI_with_GT\\benign\\benign (1).png',
#   'Dataset_BUSI_with_GT\\benign\\benign (1)_mask.png'),
#  ('Dataset_BUSI_with_GT\\benign\\benign (10).png',
#   'Dataset_BUSI_with_GT\\benign\\benign (10)_mask.png'),
#  ('Dataset_BUSI_with_GT\\benign\\benign (100).png',
#   'Dataset_BUSI_with_GT\\benign\\benign (100)_mask.png'),
#  ('Dataset_BUSI_with_GT\\benign\\benign (101).png',
#   'Dataset_BUSI_with_GT\\benign\\benign (101)_mask.png')]

# %%
len(series)
# Out:
# 780

# %%
def plot_train_labels(image_mask):
    image = cv2.imread(image_mask[0])
    mask = cv2.imread(image_mask[1])
    
    _, axarr = plt.subplots(1, 3, figsize=(5, 5))
    
    axarr[0].imshow(np.squeeze(image), cmap='gray', origin='lower')
    axarr[0].set_ylabel('Axial View', fontsize=14)
    axarr[0].set_xticks([])
    axarr[0].set_yticks([])
    axarr[0].set_title('CT', fontsize=14)

    axarr[1].imshow(np.squeeze(mask), cmap='jet', origin='lower')
    axarr[1].axis('off')
    axarr[1].set_title('Mask', fontsize=14)

    axarr[2].imshow(np.squeeze(image), cmap='gray', alpha=1, origin='lower')
    axarr[2].imshow(np.squeeze(mask), cmap='jet', alpha=0.5, origin='lower')
    axarr[2].axis('off')
    axarr[2].set_title('Overlay', fontsize=14)

    plt.tight_layout()
    plt.subplots_adjust(wspace=0, hspace=0)
    plt.show()

# %%
random_image = random.sample(range(750), 7)
for image in random_image:
    plot_train_labels(series[image])

# %%
dataset = pd.DataFrame(series, columns = ['image_path', 'mask_path'])

# %%
dataset
# Out:
#                                        image_path  \
# 0      Dataset_BUSI_with_GT\benign\benign (1).png
# 1     Dataset_BUSI_with_GT\benign\benign (10).png
# 2    Dataset_BUSI_with_GT\benign\benign (100).png
# 3    Dataset_BUSI_with_GT\benign\benign (101).png
# 4    Dataset_BUSI_with_GT\benign\benign (102).png
# ..                                            ...
# 775   Dataset_BUSI_with_GT\normal\normal (95).png
# 776   Dataset_BUSI_with_GT\normal\normal (96).png
# 777   Dataset_BUSI_with_GT\normal\normal (97).png
# 778   Dataset_BUSI_with_GT\normal\normal (98).png
# 779   Dataset_BUSI_with_GT\normal\normal (99).png
#
#                                              mask_path
# 0      Dataset_BUSI_with_GT\benign\benign (1)_mask.png
# 1     Dataset_BUSI_with_GT\benign\benign (10)_mask.png
# 2    Dataset_BUSI_with_GT\benign\benign (100)_mask.png
# 3    Dataset_BUSI_with_GT\benign\benign (101)_mask.png
# 4    Dataset_BUSI_with_GT\benign\benign (102)_mask.png
# ..                                                 ...
# 775   Dataset_BUSI_with_GT\normal\normal (95)_mask.png
# 776   Dataset_BUSI_with_GT\normal\normal (96)_mask.png
# 777   Dataset_BUSI_with_GT\normal\normal (97)_mask.png
# 778   Dataset_BUSI_with_GT\normal\normal (98)_mask.png
# 779   Dataset_BUSI_with_GT\normal\normal (99)_mask.png
#
# [780 rows x 2 columns]

# %%
train, test= train_test_split(dataset, test_size=0.25)

# %%
print(f"Train shape: {train.shape}")
print(f"Test shape: {test.shape}")
# Out:
# Train shape: (585, 2)
# Test shape: (195, 2)

# %%
from torch.utils.data import Dataset
from torchvision import transforms
from PIL import Image

class CustomImageMaskDataset(Dataset):
    np.random.seed(42)
    torch.manual_seed(42)
    def __init__(self, dataframe, image_transform = None):
        self.data = dataframe
        self.image_transform = image_transform
    
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        image_path = self.data.iloc[idx]['image_path']
        mask_path = self.data.iloc[idx]['mask_path']
        image = Image.open(image_path).convert('L')
        mask = Image.open(mask_path).convert('L')
        
        if self.image_transform:
            image = self.image_transform(image)
            mask = self.image_transform(mask)
            
        return image, mask
    
image_size = 128
train_transforms = transforms.Compose([
    transforms.Resize([image_size, image_size]),
    transforms.ToTensor(),
])
val_transforms = transforms.Compose([
    transforms.Resize([image_size, image_size]),
    transforms.ToTensor(),
])


train_dataset = CustomImageMaskDataset(train, train_transforms)
test_dataset = CustomImageMaskDataset(test, val_transforms)

batch_size = 16
train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
for batch in train_dataloader:
    # Assuming your dataset returns a tuple (inputs, targets)
    inputs, targets = batch
    
    # Print the shapes
    print("Input shape:", inputs.shape)
    print("Target shape:", targets.shape)
    break
# Out:
# Input shape: torch.Size([16, 1, 128, 128])
# Target shape: torch.Size([16, 1, 128, 128])

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cpu')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class UNet(nn.Module):
    def __init__(self):
        super(UNet, self).__init__()
        
        # Encoding path (contracting)
        self.enc1 = self.conv_block(1, 64)
        self.enc2 = self.conv_block(64, 128)
        self.enc3 = self.conv_block(128, 256)
        self.enc4 = self.conv_block(256, 512)
        
        # Bottleneck
        self.bottleneck = self.conv_block(512, 1024)
        
        # Decoding path (expanding)
        self.upconv4 = self.upconv(1024, 512)
        self.dec4 = self.conv_block(1024, 512)
        
        self.upconv3 = self.upconv(512, 256)
        self.dec3 = self.conv_block(512, 256)
        
        self.upconv2 = self.upconv(256, 128)
        self.dec2 = self.conv_block(256, 128)
        
        self.upconv1 = self.upconv(128, 64)
        self.dec1 = self.conv_block(128, 64)
        
        # Output layer (1 output channel)
        self.out_conv = nn.Conv2d(64, 1, kernel_size=1)
    
    def conv_block(self, in_channels, out_channels):
        """Block of 2 convolution layers followed by ReLU activation"""
        return nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )
    
    def upconv(self, in_channels, out_channels):
        """Upsampling layer"""
        return nn.ConvTranspose2d(in_channels, out_channels, kernel_size=2, stride=2)
    
    def forward(self, x):
        # Encoding path
        e1 = self.enc1(x)   # 1st block
        e2 = self.enc2(F.max_pool2d(e1, 2))   # 2nd block
        e3 = self.enc3(F.max_pool2d(e2, 2))   # 3rd block
        e4 = self.enc4(F.max_pool2d(e3, 2))   # 4th block

        # Bottleneck
        b = self.bottleneck(F.max_pool2d(e4, 2))

        # Decoding path
        d4 = self.upconv4(b)
        d4 = torch.cat((e4, d4), dim=1)
        d4 = self.dec4(d4)

        d3 = self.upconv3(d4)
        d3 = torch.cat((e3, d3), dim=1)
        d3 = self.dec3(d3)

        d2 = self.upconv2(d3)
        d2 = torch.cat((e2, d2), dim=1)
        d2 = self.dec2(d2)

        d1 = self.upconv1(d2)
        d1 = torch.cat((e1, d1), dim=1)
        d1 = self.dec1(d1)

        # Output layer with sigmoid activation
        out = self.out_conv(d1)
        out = torch.sigmoid(out)  # Sigmoid activation to get values between 0 and 1
        return out


# Instantiate the model and check its output shape
model = UNet()
x = torch.randn(1, 1, 128, 128)  # Example input: batch size = 1, 1 input channel, image size 572x572
output = model(x)
print(output.shape)  # Should be [1, 1, H, W] depending on the input size (matching the input spatial dimensions)
# Out:
# torch.Size([1, 1, 128, 128])

# %%
class Trainer:
    def __init__(self, model, num_epochs, optimizer, criterion, device):
        self.num_epochs = num_epochs
        self.optimizer = optimizer
        self.criterion = criterion
        self.model = model
        self.device = device
        self.log_interval = 15

        # Lists to store training and validation metrics
        self.train_losses = []
        self.val_losses = []
        self.train_dices = []
        self.val_dices = []

        # Best model and its metrics
        self.best_model = None
        self.best_dice = 0.0
        self.best_epoch = 0
        
    def dice_coeff(self, predicted, target, smooth=1e-5):
        intersection = torch.sum(predicted * target)
        union = torch.sum(predicted) + torch.sum(target)
        dice = (2. * intersection + smooth) / (union + smooth)
        return dice
    
    def iou(self, pred_mask, true_mask):
        intersection = torch.logical_and(pred_mask, true_mask).sum().item()
        union = torch.logical_or(pred_mask, true_mask).sum().item()
        iou_score = intersection / union if union != 0 else 0.0
        return iou_score
    
    def save_best_model(self, epoch, dice):
        if dice > self.best_dice:
            self.best_dice = dice
            self.best_epoch = epoch
            self.best_model = self.model.state_dict()

            filename = f'best_model_epoch{epoch}_dice{dice:.4f}.pth'
            torch.save(self.best_model, filename)
            
            
    def train(self, train_loader, val_loader):
        for epoch in range(self.num_epochs):
            train_loss = 0.0
            val_loss = 0.0
            train_dice = 0.0
            val_dice = 0.0

            # Training loop
            for i, (images, masks) in enumerate(train_loader):
                images, masks = images.to(self.device), masks.to(self.device)

                self.model.train()
                self.optimizer.zero_grad()

                outputs = self.model(images)
                loss = self.criterion(outputs, masks)
                dice = self.dice_coeff(outputs, masks)

                loss.backward()
                self.optimizer.step()

                train_loss += loss.item()
                train_dice += dice

                if (i + 1) % self.log_interval == 0:
                    print(f'Epoch [{epoch + 1}/{self.num_epochs}], Step [{i + 1}/{len(train_loader)}], Loss: {loss.item():.4f}, Dice Coef: {dice:.4f}')

            # Validation loop
            self.model.eval()
            with torch.no_grad():
                for images, masks in val_loader:
                    images, masks = images.to(self.device), masks.to(self.device)
                    outputs = self.model(images)
                    val_loss += self.criterion(outputs, masks).item()
                    val_dice += self.dice_coeff(outputs, masks)

            avg_train_loss = train_loss / len(train_loader)
            avg_val_loss = val_loss / len(val_loader)
            avg_train_dice = train_dice / len(train_loader)
            avg_val_dice = val_dice / len(val_loader)

            print(f'Epoch [{epoch + 1}/{self.num_epochs}], Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}')
            print(f'Epoch [{epoch + 1}/{self.num_epochs}], Train Dice: {avg_train_dice:.4f}, Val Dice: {avg_val_dice:.4f}')

            # Save metrics
            self.train_losses.append(avg_train_loss)
            self.val_losses.append(avg_val_loss)
            self.train_dices.append(avg_train_dice)
            self.val_dices.append(avg_val_dice)

            # Save best model
            self.save_best_model(epoch + 1, avg_val_dice)
    def get_metrics(self):
        return {
            'train_losses': self.train_losses,
            'val_losses': self.val_losses,
            'train_dices': self.train_dices,
            'val_dices': self.val_dices,
            'best_model': self.best_model,
            'best_dice': self.best_dice,
            'best_epoch': self.best_epoch
        }

# %%
def dice_coef_loss(inputs, target):
    smooth = 1e-6
    intersection = 2.0 * (target*inputs).sum() + smooth
    union = target.sum() + inputs.sum() + smooth
    return 1 - (intersection/union)

def bce_dice_loss(inputs, target):
    dice_score = dice_coef_loss(inputs, target)
    bce_loss = nn.BCELoss()
    bce_score = bce_loss(inputs, target)
    
    return bce_score + dice_score

# %%
unet = UNet().to(device)

# %%
learning_rate = 0.0001
weight_decay = 1e-6  # Regularization term to prevent overfitting

optimizer = optim.Adam(unet.parameters(), lr=learning_rate, weight_decay=weight_decay)

trainer = Trainer(model=unet, num_epochs=100, optimizer=optimizer, criterion=bce_dice_loss, device=device)

# %%
trainer.train(train_dataloader, test_dataloader)
metrics = trainer.get_metrics()
# Out:
# Epoch [1/100], Step [15/37], Loss: 1.3530, Dice Coef: 0.2082
# Epoch [1/100], Step [30/37], Loss: 1.2378, Dice Coef: 0.2584
# Epoch [1/100], Train Loss: 1.3511, Val Loss: 1.2536
# Epoch [1/100], Train Dice: 0.2012, Val Dice: 0.1550
# Epoch [2/100], Step [15/37], Loss: 1.1697, Dice Coef: 0.2502
# Epoch [2/100], Step [30/37], Loss: 1.2225, Dice Coef: 0.1827
# Epoch [2/100], Train Loss: 1.0981, Val Loss: 1.1287
# Epoch [2/100], Train Dice: 0.2747, Val Dice: 0.2834
# Epoch [3/100], Step [15/37], Loss: 1.1583, Dice Coef: 0.2271
# Epoch [3/100], Step [30/37], Loss: 0.9427, Dice Coef: 0.3399
# Epoch [3/100], Train Loss: 1.0333, Val Loss: 1.0124
# Epoch [3/100], Train Dice: 0.2998, Val Dice: 0.3096
# Epoch [4/100], Step [15/37], Loss: 1.0677, Dice Coef: 0.3053
# Epoch [4/100], Step [30/37], Loss: 1.0177, Dice Coef: 0.2645
# Epoch [4/100], Train Loss: 0.9734, Val Loss: 1.0670
# Epoch [4/100], Train Dice: 0.3300, Val Dice: 0.3265
# Epoch [5/100], Step [15/37], Loss: 1.0013, Dice Coef: 0.2951
# Epoch [5/100], Step [30/37], Loss: 0.9099, Dice Coef: 0.3541
# Epoch [5/100], Train Loss: 0.9338, Val Loss: 0.9502
# Epoch [5/100], Train Dice: 0.3468, Val Dice: 0.3189
# Epoch [6/100], Step [15/37], Loss: 0.9110, Dice Coef: 0.3467
# Epoch [6/100], Step [30/37], Loss: 1.0266, Dice Coef: 0.2390
# Epoch [6/100], Train Loss: 0.8936, Val Loss: 0.9841
# Epoch [6/100], Train Dice: 0.3643, Val Dice: 0.2685
# Epoch [7/100], Step [15/37], Loss: 0.8894, Dice Coef: 0.3587
# Epoch [7/100], Step [30/37], Loss: 0.8926, Dice Coef: 0.3363
# Epoch [7/100], Train Loss: 0.8467, Val Loss: 0.9070
# Epoch [7/100], Train Dice: 0.3910, Val Dice: 0.3410
# Epoch [8/100], Step [15/37], Loss: 0.7625, Dice Coef: 0.4398
# Epoch [8/100], Step [30/37], Loss: 0.7263, Dice Coef: 0.5040
# Epoch [8/100], Train Loss: 0.8008, Val Loss: 0.8720
# Epoch [8/100], Train Dice: 0.4167, Val Dice: 0.3637
# Epoch [9/100], Step [15/37], Loss: 0.8877, Dice Coef: 0.3567
# Epoch [9/100], Step [30/37], Loss: 0.7595, Dice Coef: 0.4577
# Epoch [9/100], Train Loss: 0.7696, Val Loss: 0.8358
# Epoch [9/100], Train Dice: 0.4341, Val Dice: 0.3829
# Epoch [10/100], Step [15/37], Loss: 0.6396, Dice Coef: 0.5365
# Epoch [10/100], Step [30/37], Loss: 0.7059, Dice Coef: 0.4890
# Epoch [10/100], Train Loss: 0.7256, Val Loss: 0.8120
# Epoch [10/100], Train Dice: 0.4600, Val Dice: 0.4126
# Epoch [11/100], Step [15/37], Loss: 0.7027, Dice Coef: 0.4700
# Epoch [11/100], Step [30/37], Loss: 0.7135, Dice Coef: 0.4512
# Epoch [11/100], Train Loss: 0.6974, Val Loss: 0.8293
# Epoch [11/100], Train Dice: 0.4779, Val Dice: 0.4139
# Epoch [12/100], Step [15/37], Loss: 0.6797, Dice Coef: 0.4709
# Epoch [12/100], Step [30/37], Loss: 0.6726, Dice Coef: 0.4889
# Epoch [12/100], Train Loss: 0.6811, Val Loss: 0.9213
# Epoch [12/100], Train Dice: 0.4867, Val Dice: 0.4142
# Epoch [13/100], Step [15/37], Loss: 0.7709, Dice Coef: 0.3952
# Epoch [13/100], Step [30/37], Loss: 0.8782, Dice Coef: 0.3625
# Epoch [13/100], Train Loss: 0.6699, Val Loss: 0.8472
# Epoch [13/100], Train Dice: 0.4949, Val Dice: 0.4158
# Epoch [14/100], Step [15/37], Loss: 0.5364, Dice Coef: 0.6131
# Epoch [14/100], Step [30/37], Loss: 0.6836, Dice Coef: 0.4541
# Epoch [14/100], Train Loss: 0.6154, Val Loss: 0.7497
# Epoch [14/100], Train Dice: 0.5314, Val Dice: 0.4545
# Epoch [15/100], Step [15/37], Loss: 0.6102, Dice Coef: 0.5753
# Epoch [15/100], Step [30/37], Loss: 0.5719, Dice Coef: 0.5451
# Epoch [15/100], Train Loss: 0.5981, Val Loss: 0.7368
# Epoch [15/100], Train Dice: 0.5414, Val Dice: 0.4509
# Epoch [16/100], Step [15/37], Loss: 0.6332, Dice Coef: 0.4883
# Epoch [16/100], Step [30/37], Loss: 0.4621, Dice Coef: 0.6649
# Epoch [16/100], Train Loss: 0.5526, Val Loss: 0.6857
# Epoch [16/100], Train Dice: 0.5714, Val Dice: 0.4931
# Epoch [17/100], Step [15/37], Loss: 0.4611, Dice Coef: 0.6552
# Epoch [17/100], Step [30/37], Loss: 0.4639, Dice Coef: 0.6438
# Epoch [17/100], Train Loss: 0.5383, Val Loss: 0.6768
# Epoch [17/100], Train Dice: 0.5810, Val Dice: 0.5073
# Epoch [18/100], Step [15/37], Loss: 0.5905, Dice Coef: 0.5200
# Epoch [18/100], Step [30/37], Loss: 0.4257, Dice Coef: 0.6963
# Epoch [18/100], Train Loss: 0.5028, Val Loss: 0.6857
# Epoch [18/100], Train Dice: 0.6086, Val Dice: 0.5199
# Epoch [19/100], Step [15/37], Loss: 0.4297, Dice Coef: 0.6636
# Epoch [19/100], Step [30/37], Loss: 0.4712, Dice Coef: 0.6403
# Epoch [19/100], Train Loss: 0.4730, Val Loss: 0.6552
# Epoch [19/100], Train Dice: 0.6292, Val Dice: 0.5059
# Epoch [20/100], Step [15/37], Loss: 0.4725, Dice Coef: 0.6198
# Epoch [20/100], Step [30/37], Loss: 0.4246, Dice Coef: 0.6602
# Epoch [20/100], Train Loss: 0.4462, Val Loss: 0.6370
# Epoch [20/100], Train Dice: 0.6488, Val Dice: 0.5281
# Epoch [21/100], Step [15/37], Loss: 0.4788, Dice Coef: 0.6017
# Epoch [21/100], Step [30/37], Loss: 0.4010, Dice Coef: 0.7038
# Epoch [21/100], Train Loss: 0.4298, Val Loss: 0.6194
# Epoch [21/100], Train Dice: 0.6599, Val Dice: 0.5310
# Epoch [22/100], Step [15/37], Loss: 0.3613, Dice Coef: 0.7118
# Epoch [22/100], Step [30/37], Loss: 0.3554, Dice Coef: 0.7274
# Epoch [22/100], Train Loss: 0.4026, Val Loss: 0.5900
# Epoch [22/100], Train Dice: 0.6806, Val Dice: 0.5650
# Epoch [23/100], Step [15/37], Loss: 0.4060, Dice Coef: 0.6884
# Epoch [23/100], Step [30/37], Loss: 0.5708, Dice Coef: 0.5035
# Epoch [23/100], Train Loss: 0.3990, Val Loss: 0.6183
# Epoch [23/100], Train Dice: 0.6833, Val Dice: 0.5638
# Epoch [24/100], Step [15/37], Loss: 0.3365, Dice Coef: 0.7439
# Epoch [24/100], Step [30/37], Loss: 0.3987, Dice Coef: 0.6829
# Epoch [24/100], Train Loss: 0.4031, Val Loss: 0.5911
# Epoch [24/100], Train Dice: 0.6804, Val Dice: 0.5678
# Epoch [25/100], Step [15/37], Loss: 0.3729, Dice Coef: 0.6989
# Epoch [25/100], Step [30/37], Loss: 0.3111, Dice Coef: 0.7537
# Epoch [25/100], Train Loss: 0.3619, Val Loss: 0.6629
# Epoch [25/100], Train Dice: 0.7124, Val Dice: 0.5486
# Epoch [26/100], Step [15/37], Loss: 0.4513, Dice Coef: 0.6182
# Epoch [26/100], Step [30/37], Loss: 0.3611, Dice Coef: 0.7103
# Epoch [26/100], Train Loss: 0.3430, Val Loss: 0.5919
# Epoch [26/100], Train Dice: 0.7282, Val Dice: 0.5625
# Epoch [27/100], Step [15/37], Loss: 0.2873, Dice Coef: 0.7744
# Epoch [27/100], Step [30/37], Loss: 0.3320, Dice Coef: 0.7357
# Epoch [27/100], Train Loss: 0.3400, Val Loss: 0.5521
# Epoch [27/100], Train Dice: 0.7317, Val Dice: 0.5907
# Epoch [28/100], Step [15/37], Loss: 0.2740, Dice Coef: 0.8255
# Epoch [28/100], Step [30/37], Loss: 0.2567, Dice Coef: 0.8031
# Epoch [28/100], Train Loss: 0.3331, Val Loss: 0.5689
# Epoch [28/100], Train Dice: 0.7373, Val Dice: 0.6115
# Epoch [29/100], Step [15/37], Loss: 0.2562, Dice Coef: 0.8359
# Epoch [29/100], Step [30/37], Loss: 0.2998, Dice Coef: 0.7521
# Epoch [29/100], Train Loss: 0.3142, Val Loss: 0.5852
# Epoch [29/100], Train Dice: 0.7512, Val Dice: 0.5752
# Epoch [30/100], Step [15/37], Loss: 0.2491, Dice Coef: 0.8086
# Epoch [30/100], Step [30/37], Loss: 0.3287, Dice Coef: 0.7206
# Epoch [30/100], Train Loss: 0.2933, Val Loss: 0.5690
# Epoch [30/100], Train Dice: 0.7677, Val Dice: 0.5919
# Epoch [31/100], Step [15/37], Loss: 0.3484, Dice Coef: 0.7070
# Epoch [31/100], Step [30/37], Loss: 0.2689, Dice Coef: 0.7838
# Epoch [31/100], Train Loss: 0.2690, Val Loss: 0.5452
# Epoch [31/100], Train Dice: 0.7858, Val Dice: 0.6094
# Epoch [32/100], Step [15/37], Loss: 0.2906, Dice Coef: 0.7565
# Epoch [32/100], Step [30/37], Loss: 0.3544, Dice Coef: 0.7072
# Epoch [32/100], Train Loss: 0.2522, Val Loss: 0.5141
# Epoch [32/100], Train Dice: 0.7995, Val Dice: 0.6330
# Epoch [33/100], Step [15/37], Loss: 0.2296, Dice Coef: 0.8267
# Epoch [33/100], Step [30/37], Loss: 0.3041, Dice Coef: 0.7479
# Epoch [33/100], Train Loss: 0.2385, Val Loss: 0.5270
# Epoch [33/100], Train Dice: 0.8092, Val Dice: 0.6267
# Epoch [34/100], Step [15/37], Loss: 0.4878, Dice Coef: 0.5798
# Epoch [34/100], Step [30/37], Loss: 0.2020, Dice Coef: 0.8429
# Epoch [34/100], Train Loss: 0.2380, Val Loss: 0.5027
# Epoch [34/100], Train Dice: 0.8110, Val Dice: 0.6453
# Epoch [35/100], Step [15/37], Loss: 0.2574, Dice Coef: 0.8033
# Epoch [35/100], Step [30/37], Loss: 0.1928, Dice Coef: 0.8571
# Epoch [35/100], Train Loss: 0.2759, Val Loss: 0.5932
# Epoch [35/100], Train Dice: 0.7871, Val Dice: 0.6020
# Epoch [36/100], Step [15/37], Loss: 0.2610, Dice Coef: 0.7780
# Epoch [36/100], Step [30/37], Loss: 0.1559, Dice Coef: 0.8920
# Epoch [36/100], Train Loss: 0.2539, Val Loss: 0.5117
# Epoch [36/100], Train Dice: 0.8029, Val Dice: 0.6386
# Epoch [37/100], Step [15/37], Loss: 0.3559, Dice Coef: 0.7398
# Epoch [37/100], Step [30/37], Loss: 0.2393, Dice Coef: 0.8139
# Epoch [37/100], Train Loss: 0.2735, Val Loss: 0.5174
# Epoch [37/100], Train Dice: 0.7884, Val Dice: 0.6546
# Epoch [38/100], Step [15/37], Loss: 0.2056, Dice Coef: 0.8555
# Epoch [38/100], Step [30/37], Loss: 0.2016, Dice Coef: 0.8493
# Epoch [38/100], Train Loss: 0.2236, Val Loss: 0.5042
# Epoch [38/100], Train Dice: 0.8257, Val Dice: 0.6437
# Epoch [39/100], Step [15/37], Loss: 0.2921, Dice Coef: 0.7517
# Epoch [39/100], Step [30/37], Loss: 0.1841, Dice Coef: 0.8662
# Epoch [39/100], Train Loss: 0.2019, Val Loss: 0.4939
# Epoch [39/100], Train Dice: 0.8419, Val Dice: 0.6524
# Epoch [40/100], Step [15/37], Loss: 0.2175, Dice Coef: 0.8120
# Epoch [40/100], Step [30/37], Loss: 0.1747, Dice Coef: 0.8550
# Epoch [40/100], Train Loss: 0.1930, Val Loss: 0.5004
# Epoch [40/100], Train Dice: 0.8469, Val Dice: 0.6616
# Epoch [41/100], Step [15/37], Loss: 0.2088, Dice Coef: 0.8226
# Epoch [41/100], Step [30/37], Loss: 0.1823, Dice Coef: 0.8640
# Epoch [41/100], Train Loss: 0.1890, Val Loss: 0.4412
# Epoch [41/100], Train Dice: 0.8519, Val Dice: 0.7009
# Epoch [42/100], Step [15/37], Loss: 0.1354, Dice Coef: 0.9021
# Epoch [42/100], Step [30/37], Loss: 0.1777, Dice Coef: 0.8762
# Epoch [42/100], Train Loss: 0.1795, Val Loss: 0.5115
# Epoch [42/100], Train Dice: 0.8592, Val Dice: 0.6516
# Epoch [43/100], Step [15/37], Loss: 0.1963, Dice Coef: 0.8403
# Epoch [43/100], Step [30/37], Loss: 0.1541, Dice Coef: 0.8771
# Epoch [43/100], Train Loss: 0.1684, Val Loss: 0.4972
# Epoch [43/100], Train Dice: 0.8672, Val Dice: 0.6611
# Epoch [44/100], Step [15/37], Loss: 0.2030, Dice Coef: 0.8329
# Epoch [44/100], Step [30/37], Loss: 0.1552, Dice Coef: 0.8801
# Epoch [44/100], Train Loss: 0.1671, Val Loss: 0.4751
# Epoch [44/100], Train Dice: 0.8659, Val Dice: 0.6773
# Epoch [45/100], Step [15/37], Loss: 0.1555, Dice Coef: 0.8870
# Epoch [45/100], Step [30/37], Loss: 0.1510, Dice Coef: 0.8809
# Epoch [45/100], Train Loss: 0.1547, Val Loss: 0.4930
# Epoch [45/100], Train Dice: 0.8774, Val Dice: 0.6671
# Epoch [46/100], Step [15/37], Loss: 0.1579, Dice Coef: 0.8777
# Epoch [46/100], Step [30/37], Loss: 0.1545, Dice Coef: 0.8718
# Epoch [46/100], Train Loss: 0.1449, Val Loss: 0.4796
# Epoch [46/100], Train Dice: 0.8849, Val Dice: 0.6879
# Epoch [47/100], Step [15/37], Loss: 0.0990, Dice Coef: 0.9305
# Epoch [47/100], Step [30/37], Loss: 0.1044, Dice Coef: 0.9288
# Epoch [47/100], Train Loss: 0.1364, Val Loss: 0.4872
# Epoch [47/100], Train Dice: 0.8915, Val Dice: 0.6755
# Epoch [48/100], Step [15/37], Loss: 0.0960, Dice Coef: 0.9266
# Epoch [48/100], Step [30/37], Loss: 0.1622, Dice Coef: 0.8585
# Epoch [48/100], Train Loss: 0.1320, Val Loss: 0.4789
# Epoch [48/100], Train Dice: 0.8948, Val Dice: 0.6838
# Epoch [49/100], Step [15/37], Loss: 0.0977, Dice Coef: 0.9285
# Epoch [49/100], Step [30/37], Loss: 0.1485, Dice Coef: 0.8717
# Epoch [49/100], Train Loss: 0.1273, Val Loss: 0.4751
# Epoch [49/100], Train Dice: 0.8991, Val Dice: 0.6904
# Epoch [50/100], Step [15/37], Loss: 0.1142, Dice Coef: 0.9061
# Epoch [50/100], Step [30/37], Loss: 0.1258, Dice Coef: 0.9096
# Epoch [50/100], Train Loss: 0.1248, Val Loss: 0.4969
# Epoch [50/100], Train Dice: 0.9009, Val Dice: 0.6766
# Epoch [51/100], Step [15/37], Loss: 0.0935, Dice Coef: 0.9265
# Epoch [51/100], Step [30/37], Loss: 0.2015, Dice Coef: 0.8226
# Epoch [51/100], Train Loss: 0.1243, Val Loss: 0.4757
# Epoch [51/100], Train Dice: 0.9013, Val Dice: 0.7037
# Epoch [52/100], Step [15/37], Loss: 0.1092, Dice Coef: 0.9115
# Epoch [52/100], Step [30/37], Loss: 0.1341, Dice Coef: 0.8974
# Epoch [52/100], Train Loss: 0.1227, Val Loss: 0.4758
# Epoch [52/100], Train Dice: 0.9036, Val Dice: 0.6945
# Epoch [53/100], Step [15/37], Loss: 0.0968, Dice Coef: 0.9272
# Epoch [53/100], Step [30/37], Loss: 0.1141, Dice Coef: 0.9031
# Epoch [53/100], Train Loss: 0.1140, Val Loss: 0.4589
# Epoch [53/100], Train Dice: 0.9104, Val Dice: 0.7033
# Epoch [54/100], Step [15/37], Loss: 0.0822, Dice Coef: 0.9372
# Epoch [54/100], Step [30/37], Loss: 0.0852, Dice Coef: 0.9371
# Epoch [54/100], Train Loss: 0.1071, Val Loss: 0.4636
# Epoch [54/100], Train Dice: 0.9155, Val Dice: 0.7045
# Epoch [55/100], Step [15/37], Loss: 0.0847, Dice Coef: 0.9361
# Epoch [55/100], Step [30/37], Loss: 0.0873, Dice Coef: 0.9344
# Epoch [55/100], Train Loss: 0.1052, Val Loss: 0.4599
# Epoch [55/100], Train Dice: 0.9171, Val Dice: 0.7110
# Epoch [56/100], Step [15/37], Loss: 0.0691, Dice Coef: 0.9520
# Epoch [56/100], Step [30/37], Loss: 0.1221, Dice Coef: 0.9007
# Epoch [56/100], Train Loss: 0.1058, Val Loss: 0.4614
# Epoch [56/100], Train Dice: 0.9163, Val Dice: 0.7214
# Epoch [57/100], Step [15/37], Loss: 0.1286, Dice Coef: 0.9020
# Epoch [57/100], Step [30/37], Loss: 0.0930, Dice Coef: 0.9293
# Epoch [57/100], Train Loss: 0.1010, Val Loss: 0.4697
# Epoch [57/100], Train Dice: 0.9208, Val Dice: 0.7014
# Epoch [58/100], Step [15/37], Loss: 0.1143, Dice Coef: 0.9060
# Epoch [58/100], Step [30/37], Loss: 0.0677, Dice Coef: 0.9526
# Epoch [58/100], Train Loss: 0.0969, Val Loss: 0.4735
# Epoch [58/100], Train Dice: 0.9240, Val Dice: 0.7016
# Epoch [59/100], Step [15/37], Loss: 0.0722, Dice Coef: 0.9507
# Epoch [59/100], Step [30/37], Loss: 0.0910, Dice Coef: 0.9304
# Epoch [59/100], Train Loss: 0.0919, Val Loss: 0.4576
# Epoch [59/100], Train Dice: 0.9277, Val Dice: 0.7179
# Epoch [60/100], Step [15/37], Loss: 0.0665, Dice Coef: 0.9495
# Epoch [60/100], Step [30/37], Loss: 0.1486, Dice Coef: 0.8649
# Epoch [60/100], Train Loss: 0.0898, Val Loss: 0.4763
# Epoch [60/100], Train Dice: 0.9292, Val Dice: 0.7083
# Epoch [61/100], Step [15/37], Loss: 0.0740, Dice Coef: 0.9476
# Epoch [61/100], Step [30/37], Loss: 0.0778, Dice Coef: 0.9369
# Epoch [61/100], Train Loss: 0.0905, Val Loss: 0.4557
# Epoch [61/100], Train Dice: 0.9277, Val Dice: 0.7189
# Epoch [62/100], Step [15/37], Loss: 0.0728, Dice Coef: 0.9449
# Epoch [62/100], Step [30/37], Loss: 0.1027, Dice Coef: 0.9101
# Epoch [62/100], Train Loss: 0.0812, Val Loss: 0.4625
# Epoch [62/100], Train Dice: 0.9365, Val Dice: 0.7146
# Epoch [63/100], Step [15/37], Loss: 0.0601, Dice Coef: 0.9556
# Epoch [63/100], Step [30/37], Loss: 0.0625, Dice Coef: 0.9547
# Epoch [63/100], Train Loss: 0.0860, Val Loss: 0.4676
# Epoch [63/100], Train Dice: 0.9316, Val Dice: 0.7120
# Epoch [64/100], Step [15/37], Loss: 0.1010, Dice Coef: 0.9131
# Epoch [64/100], Step [30/37], Loss: 0.0856, Dice Coef: 0.9308
# Epoch [64/100], Train Loss: 0.0774, Val Loss: 0.4633
# Epoch [64/100], Train Dice: 0.9395, Val Dice: 0.7167
# Epoch [65/100], Step [15/37], Loss: 0.0700, Dice Coef: 0.9405
# Epoch [65/100], Step [30/37], Loss: 0.0535, Dice Coef: 0.9616
# Epoch [65/100], Train Loss: 0.0758, Val Loss: 0.4809
# Epoch [65/100], Train Dice: 0.9405, Val Dice: 0.7032
# Epoch [66/100], Step [15/37], Loss: 0.0671, Dice Coef: 0.9473
# Epoch [66/100], Step [30/37], Loss: 0.0691, Dice Coef: 0.9437
# Epoch [66/100], Train Loss: 0.0731, Val Loss: 0.4622
# Epoch [66/100], Train Dice: 0.9427, Val Dice: 0.7180
# Epoch [67/100], Step [15/37], Loss: 0.1125, Dice Coef: 0.9010
# Epoch [67/100], Step [30/37], Loss: 0.0585, Dice Coef: 0.9540
# Epoch [67/100], Train Loss: 0.0716, Val Loss: 0.4917
# Epoch [67/100], Train Dice: 0.9441, Val Dice: 0.7003
# Epoch [68/100], Step [15/37], Loss: 0.0637, Dice Coef: 0.9518
# Epoch [68/100], Step [30/37], Loss: 0.0560, Dice Coef: 0.9594
# Epoch [68/100], Train Loss: 0.0711, Val Loss: 0.4678
# Epoch [68/100], Train Dice: 0.9444, Val Dice: 0.7197
# Epoch [69/100], Step [15/37], Loss: 0.0801, Dice Coef: 0.9323
# Epoch [69/100], Step [30/37], Loss: 0.0902, Dice Coef: 0.9236
# Epoch [69/100], Train Loss: 0.0670, Val Loss: 0.4749
# Epoch [69/100], Train Dice: 0.9475, Val Dice: 0.7153
# Epoch [70/100], Step [15/37], Loss: 0.0485, Dice Coef: 0.9674
# Epoch [70/100], Step [30/37], Loss: 0.0472, Dice Coef: 0.9659
# Epoch [70/100], Train Loss: 0.0659, Val Loss: 0.4649
# Epoch [70/100], Train Dice: 0.9484, Val Dice: 0.7220
# Epoch [71/100], Step [15/37], Loss: 0.0657, Dice Coef: 0.9449
# Epoch [71/100], Step [30/37], Loss: 0.0700, Dice Coef: 0.9438
# Epoch [71/100], Train Loss: 0.0623, Val Loss: 0.4806
# Epoch [71/100], Train Dice: 0.9516, Val Dice: 0.7142
# Epoch [72/100], Step [15/37], Loss: 0.0546, Dice Coef: 0.9572
# Epoch [72/100], Step [30/37], Loss: 0.0489, Dice Coef: 0.9633
# Epoch [72/100], Train Loss: 0.0628, Val Loss: 0.4913
# Epoch [72/100], Train Dice: 0.9511, Val Dice: 0.7057
# Epoch [73/100], Step [15/37], Loss: 0.0742, Dice Coef: 0.9360
# Epoch [73/100], Step [30/37], Loss: 0.0494, Dice Coef: 0.9637
# Epoch [73/100], Train Loss: 0.0620, Val Loss: 0.4777
# Epoch [73/100], Train Dice: 0.9516, Val Dice: 0.7176
# Epoch [74/100], Step [15/37], Loss: 0.0558, Dice Coef: 0.9549
# Epoch [74/100], Step [30/37], Loss: 0.0464, Dice Coef: 0.9669
# Epoch [74/100], Train Loss: 0.0648, Val Loss: 0.4870
# Epoch [74/100], Train Dice: 0.9493, Val Dice: 0.7134
# Epoch [75/100], Step [15/37], Loss: 0.0609, Dice Coef: 0.9505
# Epoch [75/100], Step [30/37], Loss: 0.0552, Dice Coef: 0.9571
# Epoch [75/100], Train Loss: 0.0606, Val Loss: 0.4942
# Epoch [75/100], Train Dice: 0.9531, Val Dice: 0.7058
# Epoch [76/100], Step [15/37], Loss: 0.0484, Dice Coef: 0.9633
# Epoch [76/100], Step [30/37], Loss: 0.0477, Dice Coef: 0.9664
# Epoch [76/100], Train Loss: 0.0607, Val Loss: 0.4766
# Epoch [76/100], Train Dice: 0.9525, Val Dice: 0.7194
# Epoch [77/100], Step [15/37], Loss: 0.0527, Dice Coef: 0.9635
# Epoch [77/100], Step [30/37], Loss: 0.0501, Dice Coef: 0.9624
# Epoch [77/100], Train Loss: 0.0567, Val Loss: 0.4922
# Epoch [77/100], Train Dice: 0.9561, Val Dice: 0.7101
# Epoch [78/100], Step [15/37], Loss: 0.0658, Dice Coef: 0.9457
# Epoch [78/100], Step [30/37], Loss: 0.0677, Dice Coef: 0.9431
# Epoch [78/100], Train Loss: 0.0579, Val Loss: 0.4976
# Epoch [78/100], Train Dice: 0.9551, Val Dice: 0.7114
# Epoch [79/100], Step [15/37], Loss: 0.0699, Dice Coef: 0.9396
# Epoch [79/100], Step [30/37], Loss: 0.0505, Dice Coef: 0.9607
# Epoch [79/100], Train Loss: 0.0560, Val Loss: 0.4804
# Epoch [79/100], Train Dice: 0.9564, Val Dice: 0.7232
# Epoch [80/100], Step [15/37], Loss: 0.0563, Dice Coef: 0.9566
# Epoch [80/100], Step [30/37], Loss: 0.0592, Dice Coef: 0.9580
# Epoch [80/100], Train Loss: 0.0573, Val Loss: 0.4739
# Epoch [80/100], Train Dice: 0.9555, Val Dice: 0.7248
# Epoch [81/100], Step [15/37], Loss: 0.0454, Dice Coef: 0.9662
# Epoch [81/100], Step [30/37], Loss: 0.0582, Dice Coef: 0.9566
# Epoch [81/100], Train Loss: 0.0552, Val Loss: 0.4591
# Epoch [81/100], Train Dice: 0.9572, Val Dice: 0.7357
# Epoch [82/100], Step [15/37], Loss: 0.0542, Dice Coef: 0.9595
# Epoch [82/100], Step [30/37], Loss: 0.0530, Dice Coef: 0.9562
# Epoch [82/100], Train Loss: 0.0521, Val Loss: 0.4891
# Epoch [82/100], Train Dice: 0.9594, Val Dice: 0.7161
# Epoch [83/100], Step [15/37], Loss: 0.0453, Dice Coef: 0.9691
# Epoch [83/100], Step [30/37], Loss: 0.0877, Dice Coef: 0.9378
# Epoch [83/100], Train Loss: 0.0956, Val Loss: 1.8519
# Epoch [83/100], Train Dice: 0.9332, Val Dice: 0.4946
# Epoch [84/100], Step [15/37], Loss: 0.1881, Dice Coef: 0.8472
# Epoch [84/100], Step [30/37], Loss: 0.2228, Dice Coef: 0.8437
# Epoch [84/100], Train Loss: 0.3172, Val Loss: 1.6911
# Epoch [84/100], Train Dice: 0.7891, Val Dice: 0.4268
# Epoch [85/100], Step [15/37], Loss: 0.2631, Dice Coef: 0.7768
# Epoch [85/100], Step [30/37], Loss: 0.2645, Dice Coef: 0.8320
# Epoch [85/100], Train Loss: 0.2580, Val Loss: 0.5229
# Epoch [85/100], Train Dice: 0.8186, Val Dice: 0.6842
# Epoch [86/100], Step [15/37], Loss: 0.2051, Dice Coef: 0.8623
# Epoch [86/100], Step [30/37], Loss: 0.1309, Dice Coef: 0.9018
# Epoch [86/100], Train Loss: 0.2032, Val Loss: 0.4821
# Epoch [86/100], Train Dice: 0.8591, Val Dice: 0.7021
# Epoch [87/100], Step [15/37], Loss: 0.1479, Dice Coef: 0.8899
# Epoch [87/100], Step [30/37], Loss: 0.1222, Dice Coef: 0.9045
# Epoch [87/100], Train Loss: 0.1517, Val Loss: 0.5131
# Epoch [87/100], Train Dice: 0.8911, Val Dice: 0.6762
# Epoch [88/100], Step [15/37], Loss: 0.0892, Dice Coef: 0.9361
# Epoch [88/100], Step [30/37], Loss: 0.1049, Dice Coef: 0.9247
# Epoch [88/100], Train Loss: 0.1110, Val Loss: 0.4368
# Epoch [88/100], Train Dice: 0.9193, Val Dice: 0.7369
# Epoch [89/100], Step [15/37], Loss: 0.1008, Dice Coef: 0.9236
# Epoch [89/100], Step [30/37], Loss: 0.0870, Dice Coef: 0.9399
# Epoch [89/100], Train Loss: 0.1023, Val Loss: 0.5006
# Epoch [89/100], Train Dice: 0.9262, Val Dice: 0.6930
# Epoch [90/100], Step [15/37], Loss: 0.0854, Dice Coef: 0.9467
# Epoch [90/100], Step [30/37], Loss: 0.1127, Dice Coef: 0.9074
# Epoch [90/100], Train Loss: 0.0847, Val Loss: 0.4766
# Epoch [90/100], Train Dice: 0.9373, Val Dice: 0.7078
# Epoch [91/100], Step [15/37], Loss: 0.0646, Dice Coef: 0.9535
# Epoch [91/100], Step [30/37], Loss: 0.0671, Dice Coef: 0.9505
# Epoch [91/100], Train Loss: 0.0757, Val Loss: 0.5228
# Epoch [91/100], Train Dice: 0.9436, Val Dice: 0.6773
# Epoch [92/100], Step [15/37], Loss: 0.0815, Dice Coef: 0.9288
# Epoch [92/100], Step [30/37], Loss: 0.0741, Dice Coef: 0.9437
# Epoch [92/100], Train Loss: 0.0683, Val Loss: 0.4720
# Epoch [92/100], Train Dice: 0.9488, Val Dice: 0.7204
# Epoch [93/100], Step [15/37], Loss: 0.0533, Dice Coef: 0.9610
# Epoch [93/100], Step [30/37], Loss: 0.0620, Dice Coef: 0.9620
# Epoch [93/100], Train Loss: 0.0593, Val Loss: 0.5145
# Epoch [93/100], Train Dice: 0.9551, Val Dice: 0.6930
# Epoch [94/100], Step [15/37], Loss: 0.0500, Dice Coef: 0.9655
# Epoch [94/100], Step [30/37], Loss: 0.0643, Dice Coef: 0.9474
# Epoch [94/100], Train Loss: 0.0556, Val Loss: 0.4932
# Epoch [94/100], Train Dice: 0.9576, Val Dice: 0.7090
# Epoch [95/100], Step [15/37], Loss: 0.0726, Dice Coef: 0.9402
# Epoch [95/100], Step [30/37], Loss: 0.0423, Dice Coef: 0.9710
# Epoch [95/100], Train Loss: 0.0517, Val Loss: 0.5228
# Epoch [95/100], Train Dice: 0.9604, Val Dice: 0.6895
# Epoch [96/100], Step [15/37], Loss: 0.0397, Dice Coef: 0.9697
# Epoch [96/100], Step [30/37], Loss: 0.0467, Dice Coef: 0.9655
# Epoch [96/100], Train Loss: 0.0478, Val Loss: 0.5161
# Epoch [96/100], Train Dice: 0.9637, Val Dice: 0.6987
# Epoch [97/100], Step [15/37], Loss: 0.0394, Dice Coef: 0.9719
# Epoch [97/100], Step [30/37], Loss: 0.0484, Dice Coef: 0.9629
# Epoch [97/100], Train Loss: 0.0479, Val Loss: 0.5102
# Epoch [97/100], Train Dice: 0.9630, Val Dice: 0.7052
# Epoch [98/100], Step [15/37], Loss: 0.0461, Dice Coef: 0.9647
# Epoch [98/100], Step [30/37], Loss: 0.0444, Dice Coef: 0.9632
# Epoch [98/100], Train Loss: 0.0451, Val Loss: 0.5108
# Epoch [98/100], Train Dice: 0.9655, Val Dice: 0.7044
# Epoch [99/100], Step [15/37], Loss: 0.0501, Dice Coef: 0.9605
# Epoch [99/100], Step [30/37], Loss: 0.0369, Dice Coef: 0.9739
# Epoch [99/100], Train Loss: 0.0449, Val Loss: 0.5253
# Epoch [99/100], Train Dice: 0.9656, Val Dice: 0.6964
# Epoch [100/100], Step [15/37], Loss: 0.0363, Dice Coef: 0.9747
# Epoch [100/100], Step [30/37], Loss: 0.0341, Dice Coef: 0.9775
# Epoch [100/100], Train Loss: 0.0451, Val Loss: 0.5189
# Epoch [100/100], Train Dice: 0.9653, Val Dice: 0.7006

# %%
def to_numpy(tensor):
    # Move tensor to CPU and convert to NumPy array
    return tensor.cpu().detach().item()

def plot_metrics(metrics):
    num_epochs = len(metrics['train_losses'])
    epochs = np.arange(1, num_epochs + 1)

    # Convert tensors to NumPy arrays
    train_losses_np = metrics['train_losses']
    val_losses_np = metrics['val_losses']
    train_dices_np = [to_numpy(dice) for dice in metrics['train_dices']]
    val_dices_np = [to_numpy(dice) for dice in metrics['val_dices']]

    # Plot Losses
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses_np, label='Train Loss')
    plt.plot(epochs, val_losses_np, label='Val Loss')
    plt.title('Training and Validation Losses')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    # Plot Dice Coefficients
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_dices_np, label='Train Dice')
    plt.plot(epochs, val_dices_np, label='Val Dice')
    plt.title('Training and Validation Dice Coefficients')
    plt.xlabel('Epoch')
    plt.ylabel('Dice Coefficient')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_metrics(metrics)

# %%
import matplotlib.pyplot as plt
import numpy as np

def to_numpy(tensor):
    # Move tensor to CPU and convert to NumPy array
    return tensor.cpu().detach().numpy()

def threshold_prediction(predicted, threshold=0.5):
    # Threshold predicted values
    predicted[predicted < threshold] = 0
    predicted[predicted >= threshold] = 1
    return predicted

def plot_subplots(image, mask, predicted, threshold=0.5):
    # Convert tensors to NumPy arrays
    image_np, mask_np, predicted_np = map(to_numpy, (image, mask, predicted))

    # Threshold the predicted values
    predicted_np_thresholded = threshold_prediction(predicted_np, threshold)

    fig, axes = plt.subplots(1, 3, figsize=(10, 5))  # Adjust figsize as needed

    # Plot Image, Mask, Predicted, and Thresholded Predicted
    titles = ['Image', 'Mask', 'Predicted']
    for ax, data, title in zip(axes, [image_np, mask_np, predicted_np, predicted_np_thresholded], titles):
        ax.imshow(data.squeeze(), cmap='gray' if 'Mask' in title else 'gray')
        ax.set_title(title)
        ax.axis('off')

    plt.show()

# %%
for i in [2, 3, 11, 20, 55, 67, 87, 98, 120, 130, 200, 99]:
    image = train_dataset[i][0]
    mask = train_dataset[i][1]
    im = image.to(device)
    pred = unet(im.unsqueeze(0))
    pred = pred.squeeze()

    plot_subplots(im, mask, pred)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class UNet(nn.Module):
    def __init__(self, n_channels, n_classes):
        super(UNet, self).__init__()
        self.enc1 = self.double_conv(n_channels, 64)
        self.enc2 = self.double_conv(64, 128)
        self.enc3 = self.double_conv(128, 256)
        self.enc4 = self.double_conv(256, 512)

        self.bottleneck = self.double_conv(512, 1024)

        self.upconv4 = nn.ConvTranspose2d(1024, 512, kernel_size=2, stride=2)
        self.dec4 = self.double_conv(1024, 512)
        self.upconv3 = nn.ConvTranspose2d(512, 256, kernel_size=2, stride=2)
        self.dec3 = self.double_conv(512, 256)
        self.upconv2 = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
        self.dec2 = self.double_conv(256, 128)
        self.upconv1 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
        self.dec1 = self.double_conv(128, 64)

        self.out_conv = nn.Conv2d(64, n_classes, kernel_size=1)

    def double_conv(self, in_channels, out_channels):
        return nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        x1 = self.enc1(x)
        x2 = self.enc2(F.max_pool2d(x1, 2))
        x3 = self.enc3(F.max_pool2d(x2, 2))
        x4 = self.enc4(F.max_pool2d(x3, 2))

        x_bottleneck = self.bottleneck(F.max_pool2d(x4, 2))

        x = self.upconv4(x_bottleneck)
        x = self.dec4(torch.cat([x4, x], dim=1))
        x = self.upconv3(x)
        x = self.dec3(torch.cat([x3, x], dim=1))
        x = self.upconv2(x)
        x = self.dec2(torch.cat([x2, x], dim=1))
        x = self.upconv1(x)
        x = self.dec1(torch.cat([x1, x], dim=1))
        logits = self.out_conv(x)
        return logits

# Initialize the UNet model
model = UNet(n_channels=1, n_classes=1)

# Load the pre-trained weights
model.load_state_dict(torch.load('best_model_epoch88_dice0.7369.pth', map_location=torch.device('cpu')))
model.eval()

print("Model loaded successfully!")
# Out:
# C:\Users\shash\AppData\Local\Temp\ipykernel_30332\440142112.py:59: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('best_model_epoch88_dice0.7369.pth', map_location=torch.device('cpu')))
# Model loaded successfully!

# %%
import matplotlib.pyplot as plt
import torch
from PIL import Image
import numpy as np
import torchvision.transforms as transforms
import random

# Preprocess the input image
def preprocess_image(image_path):
    """
    Preprocess the input image to match the model's training setup.
    """
    image = Image.open(image_path).convert('L')  # Convert to grayscale
    preprocess = transforms.Compose([
        transforms.Resize((128, 128)),  # Match the model input size
        transforms.ToTensor(),          # Convert to tensor
        transforms.Normalize(mean=[0.5], std=[0.5])  # Normalize (if applied during training)
    ])
    image_tensor = preprocess(image).unsqueeze(0)  # Add batch dimension
    return image_tensor, image

# Predict the mask
def predict_mask(model, image_tensor):
    """
    Predict the mask using the trained model.
    """
    with torch.no_grad():
        output = model(image_tensor)
        predicted_mask = torch.sigmoid(output).squeeze(0).cpu().numpy()
    return predicted_mask

# Visualize original, original mask, and predicted mask
def visualize_results(original_image, original_mask, predicted_mask):
    """
    Visualize the original image, original mask, and predicted mask side by side.
    """
    fig, axarr = plt.subplots(1, 3, figsize=(15, 5))

    # Original Image
    axarr[0].imshow(original_image, cmap='gray')
    axarr[0].set_title("Original Image")
    axarr[0].axis('off')

    # Original Mask
    axarr[1].imshow(original_mask, cmap='gray')
    axarr[1].set_title("Original Mask")
    axarr[1].axis('off')

    # Predicted Mask
    axarr[2].imshow(predicted_mask.squeeze(), cmap='gray')
    axarr[2].set_title("Predicted Mask")
    axarr[2].axis('off')

    plt.tight_layout()
    plt.show()

# Load the trained model
model = UNet(n_channels=1, n_classes=1)  # Ensure your UNet architecture matches
model.load_state_dict(torch.load('best_model_epoch88_dice0.7369.pth', map_location=torch.device('cpu')))
model.eval()

# Define the base path for images and masks
base_image_path = "Dataset_BUSI_with_GT/benign/benign ({}).png"
base_mask_path = "Dataset_BUSI_with_GT/benign/benign ({})_mask.png"

# Generate 5 random image numbers
random_numbers = random.sample(range(1, 100), 5)  # Adjust range based on your dataset

# Process and visualize for each random image
for number in random_numbers:
    image_path = base_image_path.format(number)
    mask_path = base_mask_path.format(number)

    # Preprocess the image
    image_tensor, original_image = preprocess_image(image_path)

    # Load the original mask
    original_mask = Image.open(mask_path).convert('L')
    original_mask = original_mask.resize((128, 128))  # Resize to match model prediction

    # Predict the mask
    predicted_mask = predict_mask(model, image_tensor)

    # Visualize results
    visualize_results(original_image, original_mask, predicted_mask)
# Out:
# C:\Users\shash\AppData\Local\Temp\ipykernel_30332\3479726553.py:59: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('best_model_epoch88_dice0.7369.pth', map_location=torch.device('cpu')))

# %%
import os
import random
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
from tqdm import tqdm
class BUSDataset(Dataset):
    def __init__(self, data_dir, transform=None):
        self.data_dir = data_dir
        self.image_files = sorted([f for f in os.listdir(data_dir) if f.endswith('.png') and '_mask' not in f])
        self.transform = transform

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        # Get image and corresponding mask paths
        image_file = self.image_files[idx]
        mask_file = image_file.replace('.png', '_mask.png')

        image_path = os.path.join(self.data_dir, image_file)
        mask_path = os.path.join(self.data_dir, mask_file)

        # Load image and mask
        image = Image.open(image_path).convert('L')
        mask = Image.open(mask_path).convert('L')

        # Apply transformations
        if self.transform:
            image = self.transform(image)
            mask = self.transform(mask)

        return image, mask

# Transformations to resize and normalize images and masks
transform = transforms.Compose([
    transforms.Resize((128, 128)),  # Match input size for the model
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])  # Normalize between -1 and 1
])

# Initialize dataset and data loader
data_dir = "Dataset_BUSI_with_GT/benign"  # Adjust path to your data
dataset = BUSDataset(data_dir, transform=transform)
data_loader = DataLoader(dataset, batch_size=4, shuffle=True)  # Adjust batch size as needed

# %%
class UNet(nn.Module):
    def __init__(self, n_channels, n_classes):
        super(UNet, self).__init__()
        self.enc1 = self.double_conv(n_channels, 64)
        self.enc2 = self.double_conv(64, 128)
        self.enc3 = self.double_conv(128, 256)
        self.enc4 = self.double_conv(256, 512)

        self.bottleneck = self.double_conv(512, 1024)

        self.upconv4 = nn.ConvTranspose2d(1024, 512, kernel_size=2, stride=2)
        self.dec4 = self.double_conv(1024, 512)
        self.upconv3 = nn.ConvTranspose2d(512, 256, kernel_size=2, stride=2)
        self.dec3 = self.double_conv(512, 256)
        self.upconv2 = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
        self.dec2 = self.double_conv(256, 128)
        self.upconv1 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
        self.dec1 = self.double_conv(128, 64)

        self.out_conv = nn.Conv2d(64, n_classes, kernel_size=1)

    def double_conv(self, in_channels, out_channels):
        return nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        x1 = self.enc1(x)
        x2 = self.enc2(nn.MaxPool2d(2)(x1))
        x3 = self.enc3(nn.MaxPool2d(2)(x2))
        x4 = self.enc4(nn.MaxPool2d(2)(x3))

        x_bottleneck = self.bottleneck(nn.MaxPool2d(2)(x4))

        x = self.upconv4(x_bottleneck)
        x = self.dec4(torch.cat([x4, x], dim=1))
        x = self.upconv3(x)
        x = self.dec3(torch.cat([x3, x], dim=1))
        x = self.upconv2(x)
        x = self.dec2(torch.cat([x2, x], dim=1))
        x = self.upconv1(x)
        x = self.dec1(torch.cat([x1, x], dim=1))
        logits = self.out_conv(x)
        return logits

# %%
def dice_loss(pred, target, smooth=1e-5):
    pred = pred.view(-1)
    target = target.view(-1)
    intersection = (pred * target).sum()
    return 1 - (2. * intersection + smooth) / (pred.sum() + target.sum() + smooth)

criterion = nn.BCEWithLogitsLoss()  # Combines sigmoid and binary cross-entropy

# %%
# Initialize model, optimizer, and device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = UNet(n_channels=1, n_classes=1).to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-3)

num_epochs = 10
for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0
    dice_score = 0

    for images, masks in tqdm(data_loader, desc=f"Epoch {epoch+1}/{num_epochs}"):
        images, masks = images.to(device), masks.to(device)

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, masks) + dice_loss(torch.sigmoid(outputs), masks)
        epoch_loss += loss.item()

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Calculate Dice Coefficient
        preds = torch.sigmoid(outputs) > 0.5
        dice_score += 1 - dice_loss(preds.float(), masks.float())

    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss:.4f}, Dice Score: {dice_score/len(data_loader):.4f}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import optim
#       2 # Initialize model, optimizer, and device
#       3 device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#
# ModuleNotFoundError: No module named 'optim'

# %%
# Visualize predictions during training
model.eval()
with torch.no_grad():
    for images, masks in data_loader:
        images, masks = images.to(device), masks.to(device)
        outputs = model(images)
        preds = torch.sigmoid(outputs) > 0.5

        # Visualize the first batch
        plt.figure(figsize=(15, 5))
        plt.subplot(1, 3, 1)
        plt.title("Original Image")
        plt.imshow(images[0].cpu().squeeze(), cmap='gray')
        plt.axis('off')

        plt.subplot(1, 3, 2)
        plt.title("Original Mask")
        plt.imshow(masks[0].cpu().squeeze(), cmap='gray')
        plt.axis('off')

        plt.subplot(1, 3, 3)
        plt.title("Predicted Mask")
        plt.imshow(preds[0].cpu().squeeze(), cmap='gray')
        plt.axis('off')

        plt.show()
        break  # Visualize one batch

# %%
torch.save(model.state_dict(), "dynamic_training_model.pth")
